# %% [markdown]
# <a href="https://colab.research.google.com/github/chemineer/Python-and-R/blob/main/Chap02_r.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("ggplot2")
library(ggplot2)
qplot(wt,mpg,data=mtcars)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# plot without title

# %%
height<-c(45,75,60,51,NA)
mean(height, na.rm=T)
# Out:
# [1] 57.75
